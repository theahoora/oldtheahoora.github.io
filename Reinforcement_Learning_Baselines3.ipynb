# %% [markdown]
# <a href="https://colab.research.google.com/github/theahoora/theahoora.github.io/blob/master/Reinforcement_Learning_Baselines3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Import dependencies**

# %%
# !pip install stable-baselines3[extra]

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # **2. Load Environment**

# %%
environment_name = 'CartPole-v1'
env = gym.make(environment_name)

# %%
environment_name

# %% [markdown]
# # **2.1. Render for Colab**

# %%
# !apt update
# !apt install xvfb

# %%
# !pip install pyvirtualdisplay

# %%
import pyvirtualdisplay

d = pyvirtualdisplay.Display()
d.start() # Start Xvfb and set "DISPLAY" environment properly.

# %%
# !pip install gym-notebook-wrapper

# %%
import gnwrapper
import gym

env = gnwrapper.LoopAnimation(gym.make('CartPole-v1', render_mode="rgb_array"))

obs = env.reset()

for _ in range(100):
    next_obs, reward, term, trunc, info = env.step(env.action_space.sample())
    env.render()

    obs = next_obs
    if term or trunc:
        obs = env.reset()

env.display()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-6c4636b7dd8e> in <cell line: 8>()
#       7
#       8 for _ in range(100):
# ----> 9     next_obs, reward, term, trunc, info = env.step(env.action_space.sample())
#      10     env.render()
#      11
#
# ...

# %% [markdown]
# # **2.2. Continue**

# %%
import gnwrapper # New Line
episodes = 5
env = gnwrapper.LoopAnimation(gym.make('CartPole-v1', render_mode="rgb_array")) # New Line
for episode in range(1, episodes+1):
  state = env.reset()
  done = False
  score = 0

  while not done:
    env.render()
    action = env.action_space.sample()
    n_state, reward, done, info = env.step(action)
    score += reward
  print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# Episode:1 Score:9.0
# Episode:2 Score:15.0
# Episode:3 Score:61.0
# Episode:4 Score:12.0
# ...

# %%
episodes = 5
for episode in range(1, episodes+1):
  print(episode)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
env.reset()
# Out:
# array([ 0.03500944,  0.01633374, -0.04014412, -0.00829563], dtype=float32)

# %%
env.observation_space.sample()
# Out:
# array([-1.2948586e-02, -7.6866869e+37, -9.5320106e-02, -2.0363722e+38],
#       dtype=float32)

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.action_space.sample()
# Out:
# 0

# %% [markdown]
# # **3. Train an RL Model**

# %%
# MAKE YOUR DIRECTORIES FIRST
log_path = os.path.join('Training', 'Logs')

# %%
log_path
# Out:
# 'Training/Logs'

# %%
import gymnasium
env = gymnasium.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 1194 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 872          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0079932865 |
# |    clip_fraction        | 0.0975       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.00393      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.84         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0135      |
# ...

# %% [markdown]
# # **4. Save and Reload Model**

# %%
PPO_Path = os.path.join('Training', 'Saved Models', 'PPO_Model_Cartpole')

# %%
model.save(PPO_Path)
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/save_util.py:278: UserWarning: Path 'Training/Saved Models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
PPO_Path
# Out:
# 'Training/Saved Models/PPO_Model_Cartpole'

# %%
del model

# %%
model = PPO.load(PPO_Path, env=env)

# %% [markdown]
# # **5. Evaluation**

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=False) # Due to the Colab
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (500.0, 0.0)

# %% [markdown]
# # **6. Test Model**

# %%
action, _ = model.predict(obs)

# %%
action
# Out:
# 0

# %%
import gnwrapper # New Line
episodes = 5
env = gnwrapper.LoopAnimation(gym.make('CartPole-v1', render_mode="rgb_array")) # New Line
for episode in range(1, episodes+1):
  obs = env.reset()
  done = False
  score = 0

  while not done:
    env.render()
    action, _ = model.predict(obs) # NOW USING MODEL HERE!!!
    obs, reward, done, info = env.step(action)
    score += reward
  print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:500.0
# Episode:2 Score:500.0
# Episode:3 Score:500.0
# Episode:4 Score:500.0
# Episode:5 Score:500.0

# %%
obs = env.reset()

# %%
model.predict(obs)
# Out:
# (array(0), None)

# %%
env.action_space.sample()
# Out:
# 1

# %%
action, _ = model.predict(obs)

# %%
env.step(action)
# Out:
# (array([ 0.01849014, -0.20785524, -0.03910314,  0.2940565 ], dtype=float32),
#  1.0,
#  False,
#  {})

# %% [markdown]
# # **7. Viewing Logs in Tensorboard**

# %%
training_log_path = os.path.join(log_path, 'PPO_2')

# %%
training_log_path
# Out:
# 'Training/Logs/PPO_2'

# %%
# !tensorboard --logdir={training_log_path}

# %% [markdown]
# # **8. Adding a callback to the training Stage**

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training, Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000, callback=eval_callback)

# %% [markdown]
# # **9. Changing Policies**

# %%
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])] # VALUE FUNCTION

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_8
# -----------------------------
# | time/              |      |
# |    fps             | 576  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015671318 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | -0.00255    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0249     |
# ...

# %% [markdown]
# # **10. Using an Alternate Algorithm**

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1275     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 137      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1184     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 204      |
# ----------------------------------
# ...
